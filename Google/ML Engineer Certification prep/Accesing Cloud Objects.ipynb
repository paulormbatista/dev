# %%
from google.cloud import bigquery
import pandas as pd
bqclient = bigquery.Client(project="duet-ai-401215")
# Perform a query.
QUERY = 'SELECT * FROM `duet-ai-401215.Generical.housing`' 
df_housing = bqclient.query(QUERY).to_dataframe()  # API request

df_housing
# Out:
#       longitude  latitude  housing_median_age  total_rooms  total_bedrooms  \
# 0       -120.00     38.52                  16         3045             543
# 1       -120.00     38.93                  17         8005            1382
# 2       -120.00     38.92                  17         1106             207
# 3       -120.00     38.92                  26          529             116
# 4       -120.00     38.90                  21         1653             419
# ...         ...       ...                 ...          ...             ...
# 2495    -124.17     41.80                  16         2739             480
# 2496    -124.17     41.76                  20         2673             538
# 2497    -123.92     41.54                  22         2920             636
# 2498    -124.15     41.81                  17         3276             628
# 2499    -124.22     41.73                  28         3003             699
#
#       population  households  median_income  median_house_value  \
# ...

# %%
from google.cloud import storage
storage_client = storage.Client(project="duet-ai-401215")
buckets = storage_client.list_buckets()
for bucket in buckets:
    print(bucket.name)
print("Listed all storage buckets.")
# Out:
# token_btc
# Listed all storage buckets.
