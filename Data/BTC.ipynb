# %%
import requests

# The API endpoint
url = "https://api.coingecko.com/api/v3/simple/token_price/usdt"
url = "https://api.coingecko.com/api/v3/coins/markets?vs_currency=usd&order=market_cap_desc"
# A GET request to the API
# Out:
# [{'id': 'bitcoin', 'symbol': 'btc', 'name': 'Bitcoin', 'image': 'https://assets.coingecko.com/coins/images/1/large/bitcoin.png?1696501400', 'current_price': 27957, 'market_cap': 544952699979, 'market_cap_rank': 1, 'fully_diluted_valuation': 586633544047, 'total_volume': 8057047991, 'high_24h': 28103, 'low_24h': 27770, 'price_change_24h': 8.8, 'price_change_percentage_24h': 0.0315, 'market_cap_change_24h': 595527149, 'market_cap_change_percentage_24h': 0.1094, 'circulating_supply': 19507931.0, 'total_supply': 21000000.0, 'max_supply': 21000000.0, 'ath': 69045, 'ath_change_percentage': -59.55871, 'ath_date': '2021-11-10T14:24:11.849Z', 'atl': 67.81, 'atl_change_percentage': 41078.3007, 'atl_date': '2013-07-06T00:00:00.000Z', 'roi': None, 'last_updated': '2023-10-08T21:17:26.392Z'}, {'id': 'ethereum', 'symbol': 'eth', 'name': 'Ethereum', 'image': 'https://assets.coingecko.com/coins/images/279/large/ethereum.png?1696501628', 'current_price': 1637.69, 'market_cap': 196802061171, 'market_cap_rank': 2, 'fully_diluted_valuation': 196802061171, 'total_volume': 5097832801, 'high_24h': 1640.83, 'low_24h': 1617.88, 'price_change_24h': 3.96, 'price_change_percentage_24h': 0.24249, 'market_cap_change_24h': 528367734, 'market_cap_change_percentage_24h': 0.2692, 'circulating_supply': 120247520.784569, 'total_supply': 120247520.784569, 'max_supply': None, 'ath': 4878.26, 'ath_change_percentage': -66.44493, 'ath_date': '2021-11-10T14:24:19.604Z', 'atl': 0.432979, 'atl_change_percentage': 377956.23334, 'atl_date': '2015-10-20T00:00:00.000Z', 'roi': {'times': 77.3185329658852, 'currency': 'btc', 'percentage': 7731.853296588519}, 'last_updated': '2023-10-08T21:17:26.427Z'}, {'id': 'tether', 'symbol': 'usdt', 'name': 'Tether', 'image': 'https://assets.coingecko.com/coins/images/325/large/Tether.png?1696501661', 'current_price': 1.001, 'market_cap': 83490677593, 'market_cap_rank': 3, 'fully_diluted_valuation': 83490677593, 'total_volume': 7919295704, 'high_24h': 1.002, 'low_24h': 0.998766, 'price_change_24h': 1.682e-05, 'price_change_percentage_24h': 0.00168, 'market_cap_change_24h': -4073017.504562378, 'market_cap_change_percentage_24h': -0.00488, 'circulating_supply': 83474442137.8166, 'total_supply': 83474442137.8166, 'max_supply': None, 'ath': 1.32, 'ath_change_percentage': -24.39464, 'ath_date': '2018-07-24T00:00:00.000Z', 'atl': 0.572521, 'atl_change_percentage': 74.7239, 'atl_date': '2015-03-02T00:00:00.000Z', 'roi': None, 'last_updated': '2023-10-08T21:15:00.343Z'}, {'id': 'binancecoin', 'symbol': 'bnb', 'name': 'BNB', 'image': 'https://assets.coingecko.com/coins/images/825/large/bnb-icon2_2x.png?1696501970', 'current_price': 211.99, 'market_cap': 32583590554, 'market_cap_rank': 4, 'fully_diluted_valuation': 42355915645, 'total_volume': 251656481, 'high_24h': 212.89, 'low_24h': 209.65, 'price_change_24h': -0.017132048531578903, 'price_change_percentage_24h': -0.00808, 'market_cap_change_24h': -10786901.878520966, 'market_cap_change_percentage_24h': -0.03309, 'circulating_supply': 153856150.0, 'total_supply': 153856150.0, 'max_supply': 200000000.0, 'ath': 686.31, 'ath_change_percentage': -69.12445, 'ath_date': '2021-05-10T07:24:17.097Z', 'atl': 0.0398177, 'atl_change_percentage': 532077.78606, 'atl_date': '2017-10-19T00:00:00.000Z', 'roi': None, 'last_updated': '2023-10-08T21:17:30.872Z'}, {'id': 'ripple', 'symbol': 'xrp', 'name': 'XRP', 'image': 'https://assets.coingecko.com/coins/images/44/large/xrp-symbol-white-128.png?1696501442', 'current_price': 0.519041, 'market_cap': 27661803935, 'market_cap_rank': 5, 'fully_diluted_valuation': 51813453964, 'total_volume': 315215104, 'high_24h': 0.523674, 'low_24h': 0.51749, 'price_change_24h': -0.002863473469252309, 'price_change_percentage_24h': -0.54866, 'market_cap_change_24h': -162026013.76378632, 'market_cap_change_percentage_24h': -0.58233, 'circulating_supply': 53387299665.0, 'total_supply': 99988380689.0, 'max_supply': 100000000000.0, 'ath': 3.4, 'ath_change_percentage': -84.73431, 'ath_date' ...

# %%
url = "https://api.coingecko.com/api/v3/simple/price?ids=bitcoin&vs_currencies=usd"
response = requests.get(url)
data = response.json()
price = data["bitcoin"]["usd"]
price
# Out:
# 27960

# %%
url = "https://api.coingecko.com/api/v3/simple/price?ids=bitcoin&vs_currencies=usd"
response = requests.get(url)
data = response.json()
price = data["bitcoin"]["usd"]
price
# Out:
# 27948
